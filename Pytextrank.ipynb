# %%
import pytextrank
import os

# %%
path_stage0 = '/Users/venkatakrishnamohansunkara/Desktop/DM/test.json'
path_stage1 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op1.json'

# %%
with open(path_stage1, 'w+') as f:
    for graf in pytextrank.parse_doc(pytextrank.json_iter(path_stage0)):
        f.write("%s\n" % pytextrank.pretty_print(graf._asdict()))
        # to view output in this notebook
        print(pytextrank.pretty_print(graf))
# Out:
# ["777", "5f3c3c6d394894c832e179582f3628be5c8c33ca", [[0, "The", "the", "DT", 0, 0], [1, "Haryana", "haryana", "NNP", 1, 1], [0, "and", "and", "CC", 0, 2], [2, "Chandigarh", "chandigarh", "NNP", 1, 3], [3, "units", "unit", "NNS", 1, 4], [0, "of", "of", "IN", 0, 5], [0, "the", "the", "DT", 0, 6], [4, "Congress", "congress", "NNP", 1, 7], [0, "will", "will", "MD", 0, 8], [5, "gherao", "gherao", "VB", 1, 9], [0, "the", "the", "DT", 0, 10], [6, "regional", "regional", "JJ", 1, 11], [7, "office", "office", "NN", 1, 12], [0, "of", "of", "IN", 0, 13], [8, "Reserve", "reserve", "NNP", 1, 14], [9, "Bank", "bank", "NNP", 1, 15], [0, "of", "of", "IN", 0, 16], [10, "India", "india", "NNP", 1, 17], [0, "on", "on", "IN", 0, 18], [11, "January", "january", "NNP", 1, 19], [0, "18", "18", "CD", 0, 20], [0, "in", "in", "IN", 0, 21], [12, "protest", "protest", "NN", 1, 22], [0, "against", "against", "IN", 0, 23], [13, "RBIs", "rbis", "NNP", 1, 24], [14, "failure", "failure", "NN", 1, 25], [0, "to", "to"
# ...

# %%
path_stage1 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op1.json'
path_stage2 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op2.json'

graph, ranks = pytextrank.text_rank(path_stage1)
pytextrank.render_ranks(graph, ranks)

with open(path_stage2, 'w') as f:
    for rl in pytextrank.normalize_key_phrases(path_stage1, ranks):
        f.write("%s\n" % pytextrank.pretty_print(rl._asdict()))
        # to view output in this notebook
        print(pytextrank.pretty_print(rl))
# Out:
# ["were", 0.02145717922891147, [29], "vbd", 14]
# ["countrys gdp", 0.020995431601157428, [52, 120], "np", 1]
# ["had", 0.020216928222842778, [21], "vbd", 15]
# ["congress", 0.01915675815807284, [4], "np", 6]
# ["reserve bank of india", 0.018348282042259786, [8, 9, 0, 10], "np", 1]
# ["demonetisation step", 0.01726958733906774, [19, 105], "np", 2]
# ["people", 0.01719871302615793, [24], "np", 3]
# ["demonetisation decision", 0.01687750774240988, [19, 46], "np", 2]
# ["meeting", 0.01622219915220692, [39], "np", 1]
# ["other places", 0.015786421894378337, [50, 51], "np", 1]
# ["mp", 0.015560260676844517, [42], "np", 2]
# ["constitutional duty", 0.01406104306958229, [16, 17], "np", 3]
# ["chandigarh", 0.012362898837057048, [2], "np", 5]
# ["regional office", 0.012333655299807074, [6, 7], "np", 1]
# ["rbi", 0.012264808622788463, [20], "np", 5]
# ["himachal pradesh viplove thakur", 0.010987942640180715, [67, 68, 69, 70], "np", 2]
# ["first time", 0.010851143087755285, [106, 18], "np", 1]
# ...

# %%
import networkx as nx
import pylab as plt

nx.draw(graph, with_labels=True) 
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# /anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:724: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(label):
# ...

# %%
path_stage1 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op1.json'
path_stage2 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op2.json'
path_stage3 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op3.json'

kernel = pytextrank.rank_kernel(path_stage2)

with open(path_stage3, 'w') as f:
    for s in pytextrank.top_sentences(kernel, path_stage1):
        f.write(pytextrank.pretty_print(s._asdict()))
        f.write("\n")
        # to view output in this notebook
        print(pytextrank.pretty_print(s._asdict()))
# Out:
# {"dist": 0.0326404815775287, "idx": 10, "text": "About the demonetisation step ,"}
# {"dist": 0.023152720079109276, "idx": 0, "text": "The Haryana and Chandigarh units of the Congress will gherao the regional office of Reserve Bank of India on January 18 in protest against RBIs failure to do its constitutional duty at the time of demonetisation ."}
# {"dist": 0.020726056323239043, "idx": 12, "text": "This decision of the Modi government has been thrust upon the people ."}
# {"dist": 0.02055646286733754, "idx": 4, "text": "To Rs 10,000 Per DayThe meeting had been summoned by senior Congress leader and Rajya Sabha MP from Himachal Pradesh Viplove Thakur and was attended among others by former Union Minister Pawan Kumar Bansal , former Haryana Minister Ajay Singh Yadav and two MLAs of the Haryana Congress ."}
# ...

# %%
path_stage2 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op2.json'
path_stage3 = '/Users/venkatakrishnamohansunkara/Desktop/DM/op3.json'

phrases = ", ".join(set([p for p in pytextrank.limit_keyphrases(path_stage2, phrase_limit=12)]))
sent_iter = sorted(pytextrank.limit_sentences(path_stage3, word_limit=150), key=lambda x: x[1])
s = []

for sent_text, idx in sent_iter:
    s.append(pytextrank.make_sentence(sent_text))

graf_text = " ".join(s)
print("**excerpts:** %s\n\n**keywords:** %s" % (graf_text, phrases,))
# Out:
# **excerpts:** The Haryana and Chandigarh units of the Congress will gherao the regional office of Reserve Bank of India on January 18 in protest against RBIs failure to do its constitutional duty at the time of demonetisation. To Rs 10,000 Per DayThe meeting had been summoned by senior Congress leader and Rajya Sabha MP from Himachal Pradesh Viplove Thakur and was attended among others by former Union Minister Pawan Kumar Bansal, former Haryana Minister Ajay Singh Yadav and two MLAs of the Haryana Congress. About the demonetisation step, This decision of the Modi government has been thrust upon the people.
#
# **keywords:** mp, demonetisation step, chandigarh, congress, other places, meeting, countrys gdp, constitutional duty, rbi, demonetisation decision, regional office, people, reserve bank of india
